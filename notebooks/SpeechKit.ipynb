# %%
# %cd ..
# Out:
# /home/oleg/audio-llm-yandex-camp

# %%
from pathlib import Path

from src.asr_eval.words_recognize_errors.generate_audio import YTextToAudioApi

# указать API ключ
# по возможности разными голосами
# проверить что ru-RU поддерживает английские вставки

def save_audio(text: str, audio_path: Path):
    if not audio_path.exists():
        model = YTextToAudioApi(api_key=..., voice=<random voice>, role=<random role>)
        # нужно чтобы работала с большими аудио
        model.synthesize(text, str(audio_path))

dir = '/large_ssd'

for i, line in enumerate(Path(f'{dir}/datasets/long_llm_texts/texts.txt').read_text().splitlines()):
    save_audio(line, Path(f'{dir}/datasets/long_llm_texts/audio_{i}.mp3'))

manga_lines = Path(f'{dir}/datasets/manga/manga.txt').read_text().splitlines()[1:]
for i, line in enumerate(manga_lines):
    save_audio(line, Path(f'{dir}/datasets/manga/audio_{i}.mp3'))

tachki_lines = Path(f'{dir}/datasets/tachki/single_variant.txt').read_text().splitlines()[1:]
for i, line in enumerate(tachki_lines):
    save_audio(line, Path(f'{dir}/datasets/tachki/audio_{i}.mp3'))
# Out:
# /large_ssd/datasets/long_llm_texts/audio_0.mp3
# /large_ssd/datasets/long_llm_texts/audio_1.mp3
# /large_ssd/datasets/long_llm_texts/audio_2.mp3
# /large_ssd/datasets/long_llm_texts/audio_3.mp3
# /large_ssd/datasets/long_llm_texts/audio_4.mp3
# /large_ssd/datasets/long_llm_texts/audio_5.mp3
# /large_ssd/datasets/long_llm_texts/audio_6.mp3
# /large_ssd/datasets/long_llm_texts/audio_7.mp3
# /large_ssd/datasets/long_llm_texts/audio_8.mp3
# /large_ssd/datasets/long_llm_texts/audio_9.mp3
# /large_ssd/datasets/long_llm_texts/audio_10.mp3
# /large_ssd/datasets/long_llm_texts/audio_11.mp3
# /large_ssd/datasets/long_llm_texts/audio_12.mp3
# /large_ssd/datasets/long_llm_texts/audio_13.mp3
# /large_ssd/datasets/long_llm_texts/audio_14.mp3
# /large_ssd/datasets/long_llm_texts/audio_15.mp3
# /large_ssd/datasets/long_llm_texts/audio_16.mp3
# /large_ssd/datasets/long_llm_texts/audio_17.mp3
# /large_ssd/datasets/long_llm_texts/audio_18.mp3
# /large_ssd/datasets/long_llm_texts/audio_19.mp3
# ...
